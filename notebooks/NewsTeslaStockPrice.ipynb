# %% [markdown]
# ## Install libraries if necessary

# %%
"""Comment out and run cell to install libraries"""
# !pip3 install ipympl
# !pip3 install ipywidgets
# !pip3 install matplotlib
# !pip3 install numpy
# !pip3 install pandas_datareader
# Out:
# Requirement already satisfied: ipympl in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (0.8.7)
# Requirement already satisfied: ipython-genutils in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: traitlets<6 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (5.1.1)
# Requirement already satisfied: numpy in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (1.23.3)
# Requirement already satisfied: ipython<9 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (8.4.0)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: matplotlib<4,>=2.0.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (3.5.2)
# Requirement already satisfied: pillow in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipympl) (9.2.0)
# Requirement already satisfied: backcall in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: colorama in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (63.4.1)
# Requirement already satisfied: decorator in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (6.15.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets<8,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib<4,>=2.0.0->ipympl) (3.0.9)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (7.3.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: psutil in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: jupyter_core in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=2.0.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (6.4.12)
# Requirement already satisfied: executing in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipympl) (302)
# Requirement already satisfied: argon2-cffi in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: jinja2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (3.0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: testpath in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: bleach in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.1.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipympl) (2.21)
# Requirement already satisfied: ipywidgets in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (7.6.5)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (8.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (6.15.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: psutil in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.5)
# Requirement already satisfied: packaging in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: pickleshare in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: backcall in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.5)
# Requirement already satisfied: stack-data in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (63.4.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: jupyter_core in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.16.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets) (302)
# Requirement already satisfied: jinja2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: nbconvert>=5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: asttokens in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.13)
# Requirement already satisfied: bleach in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: testpath in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: matplotlib in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (1.23.3)
# Collecting pandas_datareader
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Collecting pandas>=0.23
#   Downloading pandas-1.5.1-cp310-cp310-win_amd64.whl (10.4 MB)
#      --------------------------------------- 10.4/10.4 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from pandas_datareader) (2.28.1)
# Collecting lxml
#   Downloading lxml-4.9.1-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from pandas>=0.23->pandas_datareader) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.23.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\natha\anaconda3\envs\f4escientificproject\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)
# Installing collected packages: lxml, pandas, pandas_datareader
# Successfully installed lxml-4.9.1 pandas-1.5.1 pandas_datareader-0.10.0

# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader as web
import datetime
import ipympl

# %% [markdown]
# ## Functions to import price data and trading dates

# %%
def read_price_data(stock_symbol, start_date, end_date, interval):
    """Import price data from Yahoo Finance"""
    stock_data = web.get_data_yahoo(stock_symbol, start_date, end_date, interval=interval)
    price_series = stock_data.loc[:, 'Adj Close']
    price_series = price_series.fillna(method='ffill')

    return price_series

# %%
def get_date_list(stock_symbol, start_date, end_date, interval):
    """Generate list of trading dates"""
    stock_data = web.get_data_yahoo(stock_symbol, start_date, end_date, interval=interval)
    date_list = stock_data.index
    
    return date_list

# %% [markdown]
# ## Import stock data

# %%
stock_symbol = 'TSLA' # Stock symbol

# Set time period
start_date = datetime.datetime(2022, 3, 29)
end_date = datetime.datetime(2022, 9, 29)
interval = 'd' # Date interval, by default daily ('d')

# Import price series and list of trading days
try:
    date_list = get_date_list(stock_symbol, start_date, end_date, interval=interval)
    price_series = read_price_data(stock_symbol, start_date, end_date, interval=interval)
except:
    print('Import failed')

# %% [markdown]
# ## Plot price series with annotations

# %%
# Set to '%matplotlib widget' to create interactive plot (default is %matplotlib inline)
# %matplotlib widget

fig, ax = plt.subplots(figsize=(15, 8))

def getIndex(yyyy, m, d):
    index = "none"
    while index == "none":
        for x in range(len(date_list)):
            if (date_list[x] == datetime.datetime(yyyy, m, d)):
                index = x
                break
            elif datetime.datetime(yyyy, m, d) <= date_list[0]:
                return 0
        d -= 1
        if d == 0:
            d = 28
            m -= 1
            if m == 0:
                m = 12
                yyyy -= 1
    return index


def makeEvent(yyyy, m, d, text):
    index = getIndex(yyyy, m, d)
    ax.annotate(text,
            xy=(date_list[index], price_series[index]),
            xycoords='data',
            bbox=dict(boxstyle="square", fc="none", ec="gray"),
            xytext=(0, 80),
            textcoords='offset points',
            arrowprops=dict(arrowstyle='->', color='gray'),
            va='center',
            ha='left',
            fontsize=8)

# Set gridlines
plt.style.use('seaborn-whitegrid')

# Set options for interactive plot
fig.canvas.toolbar_visible = True
fig.canvas.resizable = True

# Set labels
plt.title('Stock price {}'.format(stock_symbol), fontdict = {'fontsize' : 15})
plt.xlabel('Date', fontdict = {'fontsize' : 15})
plt.ylabel('Adj. close price', fontdict = {'fontsize' : 15})

# Plot annotated price series
plt.plot(date_list, price_series)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
